# %% [markdown]
# TODO:
# 1. Улучшить качество, используя разные модели для русского и английского языка.
# 2. Итеративный подход (под вопросом) - находим кластеры, переименовываем, опять находим кластеры, переименовываем и т.д. пока количество кластеров не перестанет изменяться

# %%
import json
import os

import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
base_dir = '../'

# %%
df = pd.read_csv(f'{base_dir}output/key_skill_frequencies.csv')

# %%
# df = df[df['key_skill_frequency'] >= 5]

# %%
key_skill_names = df['key_skill_name'].tolist()
key_skill_frequencies = dict(zip(df['key_skill_name'], df['key_skill_frequency']))

# %%
if os.path.exists(f'{base_dir}/models/distiluse-base-multilingual-cased-v1'):
    model = SentenceTransformer(f'{base_dir}/models/distiluse-base-multilingual-cased-v1')

else:
    model = SentenceTransformer("sentence-transformers/distiluse-base-multilingual-cased-v1")
    model.save(f'{base_dir}/models/distiluse-base-multilingual-cased-v1')

# %%
embeddings = model.encode(df['key_skill_name'].tolist())

# %%
similarity_matrix = cosine_similarity(embeddings)

# %%
def cluster_skills_with_max_similarity(similarity_matrix, threshold):
    n = similarity_matrix.shape[0]
    clusters = []
    
    for i in range(n):
        max_similarity = 0
        best_cluster = None
        
        for cluster in clusters:
            cluster_indices = list(cluster)
            min_similarity = similarity_matrix[i, cluster_indices].min()
            
            if min_similarity >= threshold:
                avg_similarity = similarity_matrix[i, cluster_indices].mean()
                
                if avg_similarity > max_similarity:
                    max_similarity = avg_similarity
                    best_cluster = cluster
        
        if best_cluster is not None:
            best_cluster.add(i)
        else:
            clusters.append(set([i]))
    
    return clusters

# %%
clusters = cluster_skills_with_max_similarity(similarity_matrix, 0.8)

# %%
key_skill_clusters = [[key_skill_names[i] for i in cluster] for cluster in clusters]

# %%
for i, cluster in enumerate(key_skill_clusters):
    print(f"Кластер {i + 1}: {cluster}")
# Out:
# Кластер 1: ['Linux', 'Unix/Linux', 'Unix']
# Кластер 2: ['SQL', 'MySQL', 'NoSQL']
# Кластер 3: ['GitHub', 'Git', 'Gitlab']
# Кластер 4: ['PostgreeSQL', 'PostgreSQL', 'СУБД PostgreSQL', 'PostrgreSQL', 'PostgreSQL.', 'PostreSQL', 'PostgeSQL', 'PostgresSQL', 'PosgreSQL']
# Кластер 5: ['Python, Bash', 'Python']
# Кластер 6: ['Docker Compose', 'Docker', 'Docker-compose']
# Кластер 7: ['JS', 'JavaScript']
# Кластер 8: ['kubernates', 'Kubernetes', 'Kubernets', 'Kubernates', 'Kuberenetes']
# Кластер 9: ['TypeScript', 'ТypeScript']
# Кластер 10: ['CI\\CD', 'CI/CD', 'CI/СD']
# Кластер 11: ['Java', 'Java SE', 'Java EE']
# Кластер 12: ['React hook', 'React', 'ReactNative', 'React Native']
# Кластер 13: ['Ansible']
# Кластер 14: ['DevSecOps', 'DevOps']
# Кластер 15: ['PHP8', 'PHP7', 'PHP', 'PHP5']
# Кластер 16: ['управление проектом', 'Agile Project Management', 'Project management', 'Проектный менеджмент', 'Управление проектами', 'Проектное управление', 'Управление проектом', 'проектное управление']
# Кластер 17: ['Bash']
# Кластер 18: ['REST API', 'RESTful API', 'REST API/Open API']
# Кластер 19: ['HTML', 'HTML5']
# Кластер 20: ['Деловое общение', 'Деловая коммуникация', 'Деловые коммуникации']
# Кластер 21: ['WEB API', 'API', 'web-API', 'Web API']
# Кластер 22: ['English', 'Fluent English', 'Английский язык']
# Кластер 23: ['Аналитическое мышление', '• Аналитическое мышление']
# Кластер 24: ['Qt', 'QAA', 'QAM', 'AQA', 'QA', 'QoS']
# Кластер 25: ['Организаторские навыки', 'Организационные навыки']
# Кластер 26: ['CSS3', 'CSS4', 'CSS', 'CSS3+']
# Кластер 27: ['Redmine', 'Redis', 'Redux']
# Кластер 28: ['Atlassian Jira']
# Кластер 29: ['Graphite', 'Grafanagithub', 'Grafana']
# Кластер 30: ['SRE', 'REST']
# Кластер 31: ['RabbitMQ', 'Rabbit MQ', 'RabbitMQ/Kafka']
# Кластер 32: ['Деловая переписка']
# Кластер 33: ['Zabbix']
# Кластер 34: ['Тестирование', 'Приемочное тестирование', 'Тестовый стенд', 'Проведение тестирований', 'Тестирование бэкенда', 'Сквозное тестирование']
# Кластер 35: ['Node.js', 'NodeJS', 'Nest JS', 'NestJS', 'Nest.js']
# Кластер 36: ['умение работать в команде', 'Умение работать в команде', 'Навыки работы в команде', 'Работа в команде', 'Работать в команде']
# Кластер 37: ['MSSQL', 'MS SQL', 'SQL (MySQL)', 'MS SQL Server', 'SQL Server']
# Кластер 38: ['Jenkins']
# Кластер 39: ['Функциональное тестирование']
# Кластер 40: ['Администрирование сетевого оборудования']
# Кластер 41: ['Postman']
# Кластер 42: ['Навыки переговоров', 'Ведение переговоров', 'Навыки ведения переговоров', 'Переговоры', 'Проведение переговоров', 'Умение вести переговоры']
# Кластер 43: ['NixOS', 'Nginx', 'Ngnix', 'nuxt', 'Nix', 'Nutanix', 'Nuxt']
# Кластер 44: ['Promtheus', 'Prometeus', 'Prometheus']
# Кластер 45: ['C# (.NET)', 'C#/ .Net', 'C#']
# Кластер 46: ['Excel', 'MS Excel']
# Кластер 47: ['Управление командой', 'Team management']
# Кластер 48: ['Администрирование серверов Linux', 'Администрирование Linux']
# Кластер 49: ['Gulp', 'Golang', 'Gatling']
# Кластер 50: ['ClickHouse', 'ClickHouses', 'Clickhouse']
# Кластер 51: ['BPM', 'BIM', 'PMBOK', 'BPMN']
# Кластер 52: ['Kafka', 'Apache Kafka']
# Кластер 53: ['Умение работать с большим объемом информации', 'Навыки работы с большим объемом информации', 'Умение работать с большим количеством информации', 'Работа с большим объемом информации']
# Кластер 54: ['MongoDB']
# Кластер 55: ['Kotlin', 'Kotlin Coroutines', 'Kotlin coroutines']
# Кластер 56: ['Android OS', 'Android']
# Кластер 57: ['аналитические системы', 'системный аналитик', 'Системный анализ', 'System Analysis']
# Кластер 58: ['Администрирование серверов', 'администрирования серверов', 'Администрирование серверов Windows', 'Администрирование сервера', 'администрирование Windows Server']
# Кластер 59: ['АСУТП', 'АСУП', 'АСУ ТП', 'ООП']
# Кластер 60: ['Git Lab', 'GitLabCI', 'GitLab/GitHub', 'GitLab', 'GitLab CI']
# Кластер 61: ['TCP/IP', 'TCP']
# Кластер 62: ['Согласование договоров', 'Заключение договоров', 'Сопровождение договоров подряда']
# Кластер 63: ['Business Analyst', 'Бизнес-анализ', 'Бизнес-аналитика', 'Business Analysis', 'бизнес анализ', 'Анализ бизнес-процессов']
# Кластер 64: ['Исследовательский анализ данных', 'Анализ данных', 'анализа данных', 'Аналитика данных', 'аналитика данных', 'Data Analysis', 'Аналитик данных']
# Кластер 65: ['Vue.js', 'VueJS', 'vue.js', 'Vue.js v3', 'Vue.js 3', 'Vue.js3']
# Кластер 66: ['UML']
# Кластер 67: ['Настройка ПК', 'Сборка ПК']
# Кластер 68: ['Ручное тестирование', 'Мануальное тестирование', 'Manual Testing', 'Manual testing']
# Кластер 69: ['Настройка сети', 'Настройка сетевых подключений']
# Кластер 70: ['Laravel']
# Кластер 71: ['B2C продажи', 'B2B Продажи', 'B2G продажи']
# Кластер 72: ['Разработка по техническому заданию', 'Разработка технических заданий', 'Формирование технического задания для разработки']
# Кластер 73: ['Постановка задач разработчикам']
# Кластер 74: ['Terraform']
# Кластер 75: ['Microsoft Active Directory', 'MS Active Directory', 'Active Directory', 'MS ActiveDirectory']
# Кластер 76: ['ELT', 'ETL', 'ELK']
# Кластер 77: ['Программист 1С', '1С программирование']
# Кластер 78: ['Android/iOS', 'iOS']
# Кластер 79: ['Gnu C++', 'C/C++', 'C++']
# Кластер 80: ['Телефонные переговоры']
# Кластер 81: ['Atlassian Confluence', 'Atlassians']
# Кластер 82: ['Squid', 'Scrum', 'Svelte', 'Splunk']
# Кластер 83: ['Разработка проектно-сметной документации', 'Документация проекта', 'Ведение проектной документации', 'Чтение проектной документации', 'Проектная документация', 'Разработка проектной документации']
# Кластер 84: ['MS Project Expert', 'MS Project']
# Кластер 85: ['Пассивные продажи', 'Активные продажи']
# Кластер 86: ['MS Power BI', 'PowerBI', 'Power BI']
# Кластер 87: ['Навыки презентаций', 'Верстка презентаций', 'Навыки презентации', 'Подготовка презентаций', 'Проведение презентаций']
# Кластер 88: ['HTTP', 'HTTP(s)', 'HTTP/HTTPS', 'HTTPS', 'HTTP / HTTPS']
# Кластер 89: ['MS PowerPoint', 'MS SharePoint']
# Кластер 90: ['1С: Предприятие 7', '1С: Предприятие 8', '1С: Предприятие']
# Кластер 91: ['Agile']
# Кластер 92: ['VMware ESXi', 'VMware']
# Кластер 93: ['Ведение базы данных', 'Основы баз данных', 'Базы данных']
# Кластер 94: ['SAP', 'SOAP']
# Кластер 95: ['AngularJS', 'Angular 2', 'Angular 1.x', 'Angular']
# Кластер 96: ['Установка ПО', 'Настройка ПО']
# Кластер 97: ['Грамотная речь', 'Грамотная устная речь', 'Грамотная письменная речь']
# Кластер 98: ['Техническая поддержка пользователей', 'Техническая поддержка']
# Кластер 99: ['Regression testing', 'Тестирование backend', 'Регрессионное тестирование', 'Тест-дизайн', 'Регресионное тестирование', 'Регресcионное тестирование', 'Backend Testing', 'Повторное тестирование']
# Кластер 100: ['XML/Xslt', 'XML']
# Кластер 101: ['Pinia', 'Pixi', 'Pytest']
# Кластер 102: ['Figma', 'Форензика', 'Fortinet']
# Кластер 103: ['Result-oriented', 'Ориентация на результат', 'Нацелен на результат']
# Кластер 104: ['ElacticSearch', 'Elasticsearch', 'Elastic Search']
# Кластер 105: ['Поиск и привлечение клиентов']
# Кластер 106: ['Автоматизация процессов тестирования', 'Automation testing', 'Автоматизация тестирования', 'Auto Testing', 'Автоматизированное тестирование', 'автоматизация тестирования']
# Кластер 107: ['Сопровождение строительства', 'Строительство']
# Кластер 108: ['1C УХ', '1 С', '1c', '1С', '1C']
# Кластер 109: ['Аналитика', 'Аналитические исследования', 'Сквозная аналитика', 'аналитика']
# Кластер 110: ['Symfony', 'simfony']
# Кластер 111: ['ERP-системы на базе 1С']
# Кластер 112: ['Spring Framework']
# Кластер 113: ['JSON API', 'JSON']
# Кластер 114: ['SOA', 'SOLID']
# Кластер 115: ['Работа с базами данных']
# Кластер 116: ['Test case', 'test cases']
# Кластер 117: ['Webpack']
# Кластер 118: ['Selenium', 'Selenium/Selenide']
# Кластер 119: ['AutoCAD', 'Знание AutoCAD']
# Кластер 120: ['БИТ', 'БЭМ', 'BEM', 'СУБД', 'ESB', 'BI', 'БАС']
# Кластер 121: ['Swagger', 'Swegger']
# Кластер 122: ['DHCP']
# Кластер 123: ['.NET Core', 'ASP.NET Core']
# Кластер 124: ['1С-Битрикс']
# Кластер 125: ['SwiftUI', 'Swift']
# Кластер 126: ['Руководство командой', 'Руководство коллективом']
# Кластер 127: ['Windows Server 2003', 'Windows Server']
# Кластер 128: ['Администрирование', 'Удаленное администрирование']
# Кластер 129: ['Системность мышления и целеустремленность', 'Системное мышление']
# Кластер 130: ['Основы управления проектами']
# Кластер 131: ['Микрофронтовая архитектура', 'Микросервисная архитектура']
# Кластер 132: ['1С: Бухгалтерия предприятия', '1C:Бухгалтерия КОРП', '1C: Бухгалтерия', '1С: Предприятие: Бухгалтерский Учет', '1С: Бухгалтерия', '1C:Бухгалтерия']
# Кластер 133: ['Helm']
# Кластер 134: ['Управление рисками', 'Risk management']
# Кластер 135: ['PowerShell']
# Кластер 136: ['FastApi', 'FastAPI', 'Fast api']
# Кластер 137: ['Продвинутый пользователь ПК', 'Пользователь ПК', 'Уверенный пользователь ПК']
# Кластер 138: ['подготовка технико-коммерческих предложений', 'Подготовка коммерческих предложений']
# Кластер 139: ['ответственость', 'Ответственность']
# Кластер 140: ['Информационные технологии']
# Кластер 141: ['Планирование', 'Planning', 'Кадровое планирование', 'Умение планировать']
# Кластер 142: ['Ajax JQuery', 'jQuery']
# Кластер 143: ['Настройка почтовых серверов', 'Настройка серверов']
# Кластер 144: ['GO', 'go', 'Go']
# Кластер 145: ['UIKit', 'UI']
# Кластер 146: ['Microsoft Office', 'MS Office XP', 'MS Office']
# Кластер 147: ['CRM', 'Terrasoft CRM']
# Кластер 148: ['1С: Управление Торговлей', '1С: Управление холдингом', '1С: Управление Холдингом', '1С:Управление Холдингом']
# Кластер 149: ['Настройка VPN', 'VPN']
# Кластер 150: ['ASP.NET MVC', 'ASP.NET', 'ASP.NET Web API']
# Кластер 151: ['Сбор и анализ информации']
# Кластер 152: ['Django Framework', 'Django']
# Кластер 153: ['ORACLE']
# Кластер 154: ['Информационная безопасность', 'Управление информационной безопасностью', 'Information Security', 'Аудит информационной безопасности']
# Кластер 155: ['Управление бюджетом', 'Бюджетирование']
# Кластер 156: ['SpringBoot', 'Spring Boot']
# Кластер 157: ['Управление коммуникациями']
# Кластер 158: ['Ремонт ПК (блочный)', 'Ремонт ПК', 'Ремонт компьютеров']
# Кластер 159: ['Тестирование пользовательского интерфейса']
# Кластер 160: ['gRPC', 'GCD', 'GCP']
# Кластер 161: ['Многозадачность', 'Многофункциональность', 'Многопоточность']
# Кластер 162: ['Hyper-V', 'MS Hyper-V']
# Кластер 163: ['Bitrix24', 'Bitrix 24', 'bitrix24', 'Битрикс 24', 'Битрикс24']
# Кластер 164: ['Обслуживание офисной техники', 'Офисная техника']
# Кластер 165: ['DNS', 'Настройка DNS']
# Кластер 166: ['Тестирование по тест-кейсам', 'Объемное тестирование', 'Нагрузочное тестирование']
# Кластер 167: ['Развитие продаж']
# Кластер 168: ['Обучение и развитие']
# Кластер 169: ['GraphQL']
# Кластер 170: ['1С:ERP', '1C: ERP', '1С ERP', '1C ERP', '1С: ERP', '1С:ERP WE', '1C:ERP', '1С:ERP PM']
# Кластер 171: ['OpenShift']
# Кластер 172: ['UnityPro', 'UnityPr', 'Unity']
# Кластер 173: ['Жизненный цикл проекта']
# Кластер 174: ['Ведение документооборота', 'Документооборот', 'исполнительная документация', 'Ведение документации', 'Исполнительная документация', 'Документальное сопровождение', 'Бумажный документооборот', 'ведение документооборота', 'оформление документации']
# Кластер 175: ['.NET Framework']
# Кластер 176: ['TeamCity']
# Кластер 177: ['Планирование бюджета', 'План-фактный анализ бюджета']
# Кластер 178: ['Android NDK', 'Android SDK']
# Кластер 179: ['JIRA', 'Jira', 'jira']
# Кластер 180: ['Flutter']
# Кластер 181: ['back-end', 'Backend', 'backend']
# Кластер 182: ['Integration testing', 'Интеграционные тесты', 'Интеграционное тестирование', 'Тестирования интеграционных взаимодействий']
# Кластер 183: ['Разработка', 'Software Development', 'Разработка ПО']
# Кластер 184: ['Организация корпоративных мероприятий', 'Организация мероприятий', 'Corporate Events Organization']
# Кластер 185: ['Интеграция', 'Системная интеграция']
# Кластер 186: ['Удаленная работа']
# Кластер 187: ['Frontend', 'frontend', 'фронтенд', 'front-end']
# Кластер 188: ['Визуализация', 'Vue', 'vue']
# Кластер 189: ['микросервисы', 'MikroTik', 'Микросервисы']
# Кластер 190: ['Оптимизация бизнеса-процессов', 'Оптимизация процессов', 'Оптимизация производственных процессов', 'Оптимизация бизнес-процессов', 'Оптимизация бизнес процессов']
# Кластер 191: ['1С Документооборот', '1С: Документооборот']
# Кластер 192: ['Моделирование бизнес-процессов', 'Моделирование бизнес процессов']
# Кластер 193: ['Навыки продаж', 'Теплые продажи', 'продажи', 'Розничные продажи', 'Аудит продаж', 'Продажи']
# Кластер 194: ['Управление подрядчиками']
# Кластер 195: ['Оптимизация кода']
# Кластер 196: ['Техническая документация', 'Нормативно-техническая документация']
# Кластер 197: ['Ubuntu', 'Debian']
# Кластер 198: ['Тестирование API']
# Кластер 199: ['Управление ресурсами']
# Кластер 200: ['1С: Зарплата и управление персоналом']
# Кластер 201: ['Организация рабочих мест', 'Организация работы сотрудников']
# Кластер 202: ['Подбор персонала', 'Точечный подбор персонала', 'Подбор сотрудников', 'Массовый подбор персонала', 'Отбор персонала']
# Кластер 203: ['SaaS', 'Sass', 'sast']
# Кластер 204: ['Управление интернет-проектами']
# Кластер 205: ['А/В тесты', 'A/B тесты']
# Кластер 206: ['DWH', 'СХД']
# Кластер 207: ['Резервное копирование']
# Кластер 208: ['Адаптивная верстка']
# Кластер 209: ['JUnit4', 'JUnit']
# Кластер 210: ['Аналитика маркетплейсов', 'Маркетинговый анализ', 'Marketing Analysis', 'Анализ рынка', 'Аналитика рынка']
# Кластер 211: ['Yii', 'Yii2']
# Кластер 212: ['ESXi', 'UX']
# Кластер 213: ['Клиентоориентированность']
# Кластер 214: ['Управление временем', 'Time management', 'Тайм-менеджмент']
# Кластер 215: ['Визуализация данных']
# Кластер 216: ['Entity Framework', 'Entity Framework Core']
# Кластер 217: ['Hadoop']
# Кластер 218: ['Коммуникация', 'Коммуникабельность']
# Кластер 219: ['Unit тесты', 'Unit Tests', 'unit-тестов', 'UnitTest', 'Unit Testing']
# Кластер 220: ['Техническое обслуживание', 'Обслуживание оргтехники', 'Техническое обслуживание оборудования']
# Кластер 221: ['Расстановка приоритетов', 'Умение расставлять приоритеты']
# Кластер 222: ['Proxmox', 'ProxmoxVE']
# Кластер 223: ['Kibana']
# Кластер 224: ['Анализ технических требований', 'Анализ требований']
# Кластер 225: ['Financial Analysis', 'Анализ финансовых показателей', 'Финансовый анализ']
# Кластер 226: ['Системное администрирование', 'системное администрирование', 'Администрирование ОС', 'Системный администратор', 'системный администратор']
# Кластер 227: ['Kanban']
# Кластер 228: ['Автоматизация процессов', 'Автоматизация технологических процессов', 'Автоматизация бизнес-процессов']
# Кластер 229: ['CentOS']
# Кластер 230: ['IT', 'ITIL', 'ИТ']
# Кластер 231: ['Bootstrap']
# Кластер 232: ['OSA', 'AWS']
# Кластер 233: ['Flask']
# Кластер 234: ['Математическая статистика', 'Статистическая отчетность']
# Кластер 235: ['Планирование продаж', 'Sales and operations planning']
# Кластер 236: ['Adobe Acrobat', 'Adobe Photoshop', 'Adobe Illustrator']
# Кластер 237: ['Кроссбраузерная верстка']
# Кластер 238: ['С', 'C', 'С#']
# Кластер 239: ['Sales Management', 'Управление продажами']
# Кластер 240: ['Big Data']
# Кластер 241: ['Обеспечение антивирусной защиты', 'Антивирусная защита сети']
# Кластер 242: ['Виртуализация', 'Virtualization']
# Кластер 243: ['Android Studio']
# Кластер 244: ['Анализ бизнес показателей', 'коммерческая аналитика']
# Кластер 245: ['Help Desk', 'Helpdesk']
# Кластер 246: ['Алгоритмы и структуры данных', 'Алгоритмы и структуры данных Информационный поиск']
# Кластер 247: ['Холодные продажи']
# Кластер 248: ['Ms Exchange Server', 'MS Exchange']
# Кластер 249: ['Формирование аналитической отчетности']
# Кластер 250: ['Cisco', 'Cisco ASA']
# Кластер 251: ['Грамотность']
# Кластер 252: ['Разработка бизнес-требований', 'Business Development']
# Кластер 253: ['MS Visio']
# Кластер 254: ['Продуктовые метрики', 'Анализ продуктовых метрик']
# Кластер 255: ['k8', 'K8S', 'K8s', 'k8s']
# Кластер 256: ['Аналитический склад ума']
# Кластер 257: ['MS Windows', 'Windows', 'Windows Os', 'ОС Windows', 'Microsoft Windows', 'ОС Microsoft Windows']
# Кластер 258: ['Интернет-реклама']
# Кластер 259: ['Контроль работы персонала', 'Контроль сотрудников', 'Управление персоналом']
# Кластер 260: ['Контроль исполнения решений']
# Кластер 261: ['Яндекс.Вебмастер', 'Яндекс.Метрика']
# Кластер 262: ['ES5', 'ES6']
# Кластер 263: ['Маркетинговые исследования', 'Исследования рынка', 'Market Research']
# Кластер 264: ['Управление отношениями с клиентами']
# Кластер 265: ['Настройка оргтехники', 'Настройка роутеров']
# Кластер 266: ['Написание автотестов']
# Кластер 267: ['Apache Airflow']
# Кластер 268: ['Навыки работы с оргтехникой', 'Работа с оргтехникой']
# Кластер 269: ['Cucumber', 'Celery']
# Кластер 270: ['Прогнозирование', 'Прогнозирование спроса']
# Кластер 271: ['IP-телефонию', 'IP-телефония', 'SIP-телефония']
# Кластер 272: ['SCSS']
# Кластер 273: ['Прямые продажи']
# Кластер 274: ['таблицы', 'Сводные таблицы', 'Гугл таблицы', 'Tableau']
# Кластер 275: ['MVC', 'MVVM']
# Кластер 276: ['Dart']
# Кластер 277: ['Стратегическое мышление', 'Стратегическое и аналитическое мышление']
# Кластер 278: ['Рефакторинг кода']
# Кластер 279: ['Greenplum', 'GreenPlam']
# Кластер 280: ['• Управленческие навыки', 'Управленческие навыки']
# Кластер 281: ['Консультирование клиентов', 'Консультирование клиентов по телефону']
# Кластер 282: ['Xcode', 'XcodeGen']
# Кластер 283: ['Ведение переписки']
# Кластер 284: ['Selenoid', 'Selenide']
# Кластер 285: ['Креативность', 'Creatio', 'Творчество']
# Кластер 286: ['Планирование ресурсов', 'Ресурсное планирование']
# Кластер 287: ['Управление бэклогом', 'Управление стейкхолдерами']
# Кластер 288: ['Автоматизация', 'Автотестирование']
# Кластер 289: ['Open stack', 'OpenStack']
# Кластер 290: ['Монтаж инженерных систем', 'Инженерные системы']
# Кластер 291: ['Apache Maven']
# Кластер 292: ['Установка драйверов']
# Кластер 293: ['ReactJS', 'react.js', 'React JS', 'reactJS', 'React.js', 'React.JS']
# Кластер 294: ['Проектная деятельность', 'Проектная работа']
# Кластер 295: ['Gradle']
# Кластер 296: ['Анализ продаж', 'анализ динамики продаж', 'Анализ воронки продаж', 'Аналитика продаж']
# Кластер 297: ['MODX', 'Mobx', 'mobx', 'MobX', 'mobX']
# Кластер 298: ['Puppeteer', 'Puppet']
# Кластер 299: ['TestNG', 'TestIT', 'testIT']
# Кластер 300: ['Работа в условиях многозадачности', 'работа в условиях многозадачности', 'Умение работать в условиях многозадачности']
# Кластер 301: ['Статистический анализ', 'Статистика']
# Кластер 302: ['Erlang', 'Allure']
# Кластер 303: ['Анализ конкурентов', 'Конкурентная аналитика', 'Анализ конкурентной среды', 'конкурентный анализ']
# Кластер 304: ['Коммуникационные навыки', 'Коммуникативные навыки']
# Кластер 305: ['Лидерство']
# Кластер 306: ['1С: Комплексная автоматизация', '1С:Комплексная автоматизация']
# Кластер 307: ['Продвижение бренда', 'Развитие бренда']
# Кластер 308: ['Digital Marketing']
# Кластер 309: ['Веб-программирование']
# Кластер 310: ['ERP system', 'ERP-системы', 'ERP Systems', 'ERP']
# Кластер 311: ['Стрессоустойчивость']
# Кластер 312: ['next.JS', 'Next.js', 'NextJS', 'Next.JS', 'next.js']
# Кластер 313: ['HAProxy']
# Кластер 314: ['Обучение персонала']
# Кластер 315: ['Точность и внимательность', 'Точность и внимательность к деталям']
# Кластер 316: ['Описание бизнес процессов', 'Нотации описания бизнес-процессов', 'Описание бизнес-процессов', 'Понимание бизнес-процессов']
# Кластер 317: ['SSR']
# Кластер 318: ['Экономический анализ']
# Кластер 319: ['MS Outlook']
# Кластер 320: ['1С: Управление Производственным Предприятием', '1С: Управление предприятием']
# Кластер 321: ['Управление ожиданиями']
# Кластер 322: ['google sheets', 'Google Docs']
# Кластер 323: ['Linux Servers', 'Ubuntu Server']
# Кластер 324: ['Web Sockets', 'WebSockets', 'websockets', 'Websockets', 'websocket', 'Websocket', 'WebSocket']
# Кластер 325: ['Системы видеонаблюдения', 'Система видеонаблюдения']
# Кластер 326: ['Asterisk']
# Кластер 327: ['KVM']
# Кластер 328: ['Веб-дизайн', 'Web-дизайн']
# Кластер 329: ['Сопровождение клиентов', 'Ориентация на клиента']
# Кластер 330: ['User Story Mapping', 'User Story']
# Кластер 331: ['Менеджмент качества', 'Управление качеством', 'Контроль качества']
# Кластер 332: ['VLAN', 'VxLAN']
# Кластер 333: ['Confluence', 'confluence']
# Кластер 334: ['Bitrix', 'Битрикс']
# Кластер 335: ['Договорная работа']
# Кластер 336: ['Работа в CRM системе', 'Работа с CRM']
# Кластер 337: ['rxJS', 'RxJS', 'RxJava']
# Кластер 338: ['Управление бизнес процессами', 'Управление процессами', 'Административный процесс', 'Business Process Management']
# Кластер 339: ['Maven']
# Кластер 340: ['Оперативный поиск информации в сети Интернет', 'Поиск информации в интернет', 'оперативный поиск информации в сети Интернет']
# Кластер 341: ['IDA', 'IaC', 'IaaS', 'IAC', 'OSI']
# Кластер 342: ['Организация встреч', 'Организация совещаний', 'Организация деловых встреч', 'Организация конференций']
# Кластер 343: ['Bitbucket']
# Кластер 344: ['Google Analytics']
# Кластер 345: ['Разработка стратегии развития', 'Стратегия Развития']
# Кластер 346: ['TestRail']
# Кластер 347: ['Управление организационными изменениями', 'Управление изменениями']
# Кластер 348: ['Ajax']
# Кластер 349: ['Charles Proxy']
# Кластер 350: ['MES', 'MME', 'МСЭ', 'WMS', 'МИС', 'MSA', 'MIPS', 'IMS', 'SMM']
# Кластер 351: ['NuxtJs', 'nuxt.js', 'NuxtJS', 'Nuxt.js']
# Кластер 352: ['Работа с документами', 'Работа с документацией', 'Работа с проектной документацией']
# Кластер 353: ['Финансовое планирование']
# Кластер 354: ['дизайн проекты', 'Проектирование', 'Дизайн', 'Design']
# Кластер 355: ['строительно-монтажные работы', 'Производство строительно-монтажных работ']
# Кластер 356: ['WEB аналитика', 'Веб-аналитика']
# Кластер 357: ['Nexus']
# Кластер 358: ['DWDM', 'DDD', 'DRF', 'DDL', 'TDD', 'DFS']
# Кластер 359: ['Ведение отчетности', 'Подготовка отчетов']
# Кластер 360: ['Дизайн интерфейсов', 'Проектирование пользовательских интерфейсов']
# Кластер 361: ['Keycloak', 'keycloak', 'KeyCloak', 'KeyChain']
# Кластер 362: ['Playwright']
# Кластер 363: ['Selenium IDE']
# Кластер 364: ['ktor', 'kafka']
# Кластер 365: ['IT-инфраструктура', 'ИТ-архитектура', 'ИТ-инфраструктура']
# Кластер 366: ['Локальные сети', 'Региональные сети']
# Кластер 367: ['Fiddler', 'Форсайт', 'FIrewall']
# Кластер 368: ['Интернет маркетинг', 'Internet Marketing', 'Интернет-маркетинг']
# Кластер 369: ['Vitess', 'Vite', 'Veeam']
# Кластер 370: ['Обновление конфигурации 1С']
# Кластер 371: ['Функциональные требования', 'Разработка функциональных требований']
# Кластер 372: ['Чтение чертежей']
# Кластер 373: ['Финансовое моделирование', 'Подготовка финансовых моделей', 'Финансовые модели']
# Кластер 374: ['ORM']
# Кластер 375: ['Выбор подрядных организаций']
# Кластер 376: ['Финансовая отчетность']
# Кластер 377: ['Power Query M', 'Power Query']
# Кластер 378: ['Hibernate', 'Hibernate ORM']
# Кластер 379: ['Логистика', 'Логистика поставок', 'Складская логистика']
# Кластер 380: ['Закупки']
# Кластер 381: ['Windows 7-11', 'Windows 7', 'Windows 7/10']
# Кластер 382: ['Электронная коммерция', 'E-Commerce']
# Кластер 383: ['Электронный документооборот']
# Кластер 384: ['Делегирование']
# Кластер 385: ['Oracle Pl/SQL', 'Oracle/PostreSQL']
# Кластер 386: ['Waterfall']
# Кластер 387: ['Transact-SQL']
# Кластер 388: ['SEO']
# Кластер 389: ['Работа с клиентами', 'Работа с ключевыми клиентами']
# Кластер 390: ['Закупка оборудования', 'Закупка оргтехники и оборудования']
# Кластер 391: ['pandas']
# Кластер 392: ['Yandex Cloud', 'Google Clouds', 'Яндекс Cloud']
# Кластер 393: ['Управление строительством', 'Управление строительством объекта']
# Кластер 394: ['macOS', 'Mac Os', 'MacOS']
# Кластер 395: ['Мотивация сотрудников', 'Мотивация персонала']
# Кластер 396: ['devTools', 'DevTools', 'Devtools']
# Кластер 397: ['GPO']
# Кластер 398: ['Objective-C']
# Кластер 399: ['Умение работать в коллективе', 'Работа в коллективе']
# Кластер 400: ['Charles']
# Кластер 401: ['RDP', 'RDS']
# Кластер 402: ['1С:Предприятие.Элемент', '1С: Предприятие: Розница', '1C: Предприятие']
# Кластер 403: ['Формирование управленческой отчетности', 'Подготовка управленческой отчетности', 'Управленческая отчетность']
# Кластер 404: ['Miro']
# Кластер 405: ['Стратегическое планирование']
# Кластер 406: ['SLA', 'STL', 'SPL', 'SLES']
# Кластер 407: ['Revit', 'Рекрутмент', 'Рекрутинг', 'Рерайтинг']
# Кластер 408: ['Управление конфликтами']
# Кластер 409: ['Системный подход']
# Кластер 410: ['Firebase']
# Кластер 411: ['Сетевые протоколы']
# Кластер 412: ['Less']
# Кластер 413: ['async', 'asyncio', 'Asyncio']
# Кластер 414: ['Teamleading', 'Teambuilding']
# Кластер 415: ['DAX', 'MDX']
# Кластер 416: ['Стратегия управления персоналом', 'Стратегический менеджмент']
# Кластер 417: ['Исполнительность', 'Пунктуальность']
# Кластер 418: ['Сбор требований']
# Кластер 419: ['Прототипирование']
# Кластер 420: ['Написание текстов', 'Написание информационных текстов']
# Кластер 421: ['Документирование требований', 'Документирование бизнес-требований']
# Кластер 422: ['MS Word']
# Кластер 423: ['Scala']
# Кластер 424: ['Умение принимать решения', 'Умение принимать решение']
# Кластер 425: ['Оценка потребностей клиентов']
# Кластер 426: ['Azure', 'Azure DevOps']
# Кластер 427: ['управление задачами', 'Контроль выполнения задач']
# Кластер 428: ['HR-аналитика', 'HR аналитика']
# Кластер 429: ['Маркетинговые коммуникации']
# Кластер 430: ['Розничная торговля', 'торговая площадка', 'Торговая площадка']
# Кластер 431: ['Java Script']
# Кластер 432: ['Appium']
# Кластер 433: ['CleanArchitecture', 'Clean Architecture']
# Кластер 434: ['Mariadb', 'MariaDB', 'MariyaDB']
# Кластер 435: ['Доработка сайтов', 'Продвижение сайтов', 'Верстка сайтов', 'Ведение сайтов', 'Адаптация сайтов']
# Кластер 436: ['Административная поддержка руководителя']
# Кластер 437: ['Xsd', 'GetX']
# Кластер 438: ['Диагностика неисправностей']
# Кластер 439: ['SQL Alchemy', 'SQLAlchemy']
# Кластер 440: ['QEMU', 'MQTT', 'MQ', 'QML', 'AMQP']
# Кластер 441: ['Высшее образование']
# Кластер 442: ['тестирование гипотез', 'Теория тестирования']
# Кластер 443: ['.NET', '.net', '.Net']
# Кластер 444: ['Ruby']
# Кластер 445: ['VBA']
# Кластер 446: ['Vue 2/3', 'Vue 3', 'Vue2', 'Vue3']
# Кластер 447: ['мобильные приложения', 'Мобильные приложения', 'мобильные приложение', 'Тестирование мобильных приложений']
# Кластер 448: ['Контроль бюджета']
# Кластер 449: ['1C: Финансы']
# Кластер 450: ['SGW', 'ГОСТ', 'GSAP', 'ГРЭС', 'ГИС', 'ГИП', 'ПГС']
# Кластер 451: ['Дизайн интерьера']
# Кластер 452: ['UseCase', 'Use case', 'use cases']
# Кластер 453: ['SCIP', 'IPSec', 'SIP']
# Кластер 454: ['Анализ эффективности маркетинговых кампаний', 'Анализ эффективности PR-кампании']
# Кластер 455: ['ABC-анализ', 'Анализ АБС']
# Кластер 456: ['Настройка принтеров']
# Кластер 457: ['Lodash', 'Loki', 'Locust']
# Кластер 458: ['Внимательность']
# Кластер 459: ['Leadership Skills']
# Кластер 460: ['СКУД', 'SCADA', 'ЕСКД', 'СКД']
# Кластер 461: ['Финансовые показатели']
# Кластер 462: ['OpenVPN', 'Open vpn']
# Кластер 463: ['Взаимодействие с разрешительными органами', 'Взаимодействие с надзорными организациями', 'Взаимодействие с субподрядными организациями']
# Кластер 464: ['Istio']
# Кластер 465: ['Spring', 'spring']
# Кластер 466: ['маркетплейсы', 'Маркетинг', 'Маркетплейсы', 'Маркетплейс']
# Кластер 467: ['CustDev']
# Кластер 468: ['YouTrack']
# Кластер 469: ['Boost']
# Кластер 470: ['IPTables']
# Кластер 471: ['Медиапланирование']
# Кластер 472: ['ArgoCD', 'argoCD']
# Кластер 473: ['LMS', 'LLM', 'ML', 'DML']
# Кластер 474: ['Инициативность']
# Кластер 475: ['Мониторинг рынка']
# Кластер 476: ['LINQ']
# Кластер 477: ['Внутренний контроль', 'Внутренний аудит']
# Кластер 478: ['Ведение деловой переписки']
# Кластер 479: ['LDAP', 'LDPC']
# Кластер 480: ['Django Rest Framework']
# Кластер 481: ['Groovy']
# Кластер 482: ['Ruby On Rails']
# Кластер 483: ['1C: Зарплата и кадры', '1С: Зарплата и кадры']
# Кластер 484: ['MRCP', 'amoCRM']
# Кластер 485: ['LAN']
# Кластер 486: ['Service Desk']
# Кластер 487: ['Dagger']
# Кластер 488: ['Брендинг', 'Онбординг']
# Кластер 489: ['JMeter', 'Jmeter', 'jmeter']
# Кластер 490: ['Lean', 'Лизинг']
# Кластер 491: ['Навыки межличностного общения']
# Кластер 492: ['Планирование строительных работ', 'Календарный план строительства']
# Кластер 493: ['Составление договоров']
# Кластер 494: ['Cypress', 'Сypress']
# Кластер 495: ['Метрики', 'Сметы', 'Сметтер']
# Кластер 496: ['Работа с поставщиками', 'работа с подрядчиками']
# Кластер 497: ['postgres', 'Postgres', 'Postgress']
# Кластер 498: ['Spark']
# Кластер 499: ['Производственная стратегия', 'Продуктовая стратегия']
# Кластер 500: ['Аналитические способности', 'Аналитические навыки', 'Analytical skills']
# Кластер 501: ['ITIL/ITSM', 'ITSM']
# Кластер 502: ['EPC', 'ЭЦП', 'EPS']
# Кластер 503: ['Грамотная письменная и устная речь', 'Грамотная устная и письменная речь']
# Кластер 504: ['Graylog', 'GrayLog']
# Кластер 505: ['SVN']
# Кластер 506: ['Bug Reporting']
# Кластер 507: ['Холодные звонки']
# Кластер 508: ['Электрические системы и слаботочные системы']
# Кластер 509: ['LTE']
# Кластер 510: ['MVP']
# Кластер 511: ['Закупка товаров и услуг']
# Кластер 512: ['mobile', 'Mobile', 'Мобильность']
# Кластер 513: ['Shell Scripting', 'Unix Shell Scripts']
# Кластер 514: ['Интерпретация данных']
# Кластер 515: ['Check-list']
# Кластер 516: ['Работа с возражениями', 'Навыки работы с возражениями']
# Кластер 517: ['Retrofit']
# Кластер 518: ['Стратегия продаж']
# Кластер 519: ['Составление смет', 'Составление вакансий']
# Кластер 520: ['Event Management', 'Event-менеджер']
# Кластер 521: ['Мониторинг сделок', 'Мониторинг']
# Кластер 522: ['производство', 'Производственный учет', 'Делопроизводство', 'Production', 'Продюсирование', 'Бережливое производство']
# Кластер 523: ['jest', 'Jest']
# Кластер 524: ['Лизинговые операции']
# Кластер 525: ['MS IIS', 'IIS']
# Кластер 526: ['Smoke-тестирование', 'smoke тестирование', 'Smoke тестирование', 'Smoke-тесты']
# Кластер 527: ['Обучаемость', 'Обучение', 'Готовность обучаться']
# Кластер 528: ['CMake', 'cmake']
# Кластер 529: ['Формирование границ проекта']
# Кластер 530: ['Внутренние коммуникации']
# Кластер 531: ['CMS Wordpress', 'Wordpress']
# Кластер 532: ['1С: УНФ', '1С:УСО', '1С:УХ', '1С: УХ', '1С: УСО', '1С: БГУ', '1С:ЗКГУ', '1С:БГУ', '1С: Розница', '1С:ЗУП', '1С:ТОиР', '1С: УАТ', '1С:УПО']
# Кластер 533: ['Организация рабочего процесса', 'Организация учебного процесса']
# Кластер 534: ['SPA']
# Кластер 535: ['Game Programming']
# Кластер 536: ['Apache HTTP Server']
# Кластер 537: ['Анализ рисков']
# Кластер 538: ['microservices', 'Microservices']
# Кластер 539: ['Деловая этика']
# Кластер 540: ['Web', 'WEB', 'WebVitals', 'web']
# Кластер 541: ['Анализ целевой аудитории']
# Кластер 542: ['TypeORM']
# Кластер 543: ['Анализ инвестиционных проектов', 'Оценка инвестиционных проектов', 'Инвестиционные проекты']
# Кластер 544: ['MaterialUI', 'Material-UI', 'Material UI']
# Кластер 545: ['Data', 'DataOps', 'DataLens']
# Кластер 546: ['Tomcat', 'Apache Tomcat']
# Кластер 547: ['Модульное тестирование']
# Кластер 548: ['Выявление потребностей']
# Кластер 549: ['IT Recruitment']
# Кластер 550: ['Скрупулезность', 'Целеустремленность', 'Бескомпромиссность', 'Чистоплотность']
# Кластер 551: ['Trello']
# Кластер 552: ['Microsoft Access', 'MS Access']
# Кластер 553: ['Математический анализ']
# Кластер 554: ['Анализ ассортиментной линейки']
# Кластер 555: ['blockchain', 'Blockchain']
# Кластер 556: ['Diameter', 'Appmetrica']
# Кластер 557: ['Бухгалтерская отчетность', 'Бухгалтерский учёт', 'Бухгалтерский учет']
# Кластер 558: ['Сетевые технологии', 'сетевые технологии', 'знание сетевых технологий']
# Кластер 559: ['Memcached', 'Memcache', 'Cache']
# Кластер 560: ['Ceph']
# Кластер 561: ['Инженерная инфраструктура и сети']
# Кластер 562: ['sentry', 'Sentry']
# Кластер 563: ['Kotlin Multiplatform']
# Кластер 564: ['Настройка оборудования', 'приборостроение', 'Монтаж оборудования']
# Кластер 565: ['Выездные мероприятия']
# Кластер 566: ['Финансовый менеджмент', 'Основы финансового менеджмента']
# Кластер 567: ['Графический дизайн', 'Полиграфический дизайн']
# Кластер 568: ['AirFLow', 'Airflow']
# Кластер 569: ['Внедрение конфигурации 1С', 'Создание конфигурации 1С']
# Кластер 570: ['Ценообразование']
# Кластер 571: ['VoIP']
# Кластер 572: ['Разработка нового продукта', 'Разработка продукта', 'Развитие продукта']
# Кластер 573: ['Исполнение личных поручений руководителя']
# Кластер 574: ['Тестирование ПО']
# Кластер 575: ['DBus', 'DBeaver']
# Кластер 576: ['Spring Cloud']
# Кластер 577: ['Запуск новых продуктов', 'Запуск нового продукта']
# Кластер 578: ['Строительное делопроизводство']
# Кластер 579: ['проектные продажи', 'Проектные продажи', 'Продажи в проектировании']
# Кластер 580: ['Лидогенерация']
# Кластер 581: ['слаботочные системы']
# Кластер 582: ['Logstash', 'Verilog', 'logcat']
# Кластер 583: ['Участие в Тендерах']
# Кластер 584: ['План-факт анализ']
# Кластер 585: ['apache', 'Apache']
# Кластер 586: ['Проектирование зданий и сооружений', 'проектирование жилых зданий']
# Кластер 587: ['SoapUI']
# Кластер 588: ['Контекстная реклама', 'Баннерная реклама', 'Реклама', 'Cоциальная реклама', 'Наружная реклама']
# Кластер 589: ['Apache Cassandra', 'Cassandra']
# Кластер 590: ['Извлечение данных']
# Кластер 591: ['IDEF0', 'IDEF']
# Кластер 592: ['open search', 'Opensearch', 'opensearch', 'OpenSearch']
# Кластер 593: ['взаимодействие с заказчиками', 'коммуникация с клиентом', 'Взаимодействие с заказчиком']
# Кластер 594: ['Консалтинг', 'КонсультантПлюс', 'Консультирование']
# Кластер 595: ['Ведение отчётности', 'Написание отчетов']
# Кластер 596: ['Управление знаниями\u200e']
# Кластер 597: ['Highload', 'High Load', 'HighLoad', 'highload']
# Кластер 598: ['App', 'AppsFlyer']
# Кластер 599: ['Контроль и анализ ценообразования']
# Кластер 600: ['Дегустации', 'Казначейство', 'Наставничество']
# Кластер 601: ['Управление бухгалтерией', 'Управленческий учет', 'Account Management']
# Кластер 602: ['Гражданское строительство']
# Кластер 603: ['Асинхронное программирование']
# Кластер 604: ['Анализ ценообразования']
# Кластер 605: ['Разработка инструкций']
# Кластер 606: ['Способность работать в режиме многозадачности', 'Работа в режиме многозадачности', 'Умение работать в режиме многозадачности', 'Навыки работы в режиме многозадачности']
# Кластер 607: ['Маркетинговые метрики']
# Кластер 608: ['Знание офисных программ', 'Офисные программы']
# Кластер 609: ['Тендеры', 'Таргетинг']
# Кластер 610: ['Vuex', 'VFX']
# Кластер 611: ['проведение переговоров с первыми лицами компании', 'переговоры с первыми лицами компаний']
# Кластер 612: ['Финансовый аудит', 'Финансовый контроль', 'Financial Controlling']
# Кластер 613: ['Техническая экспертность', 'Техническая экспертиза']
# Кластер 614: ['Кроссбраузерное тестирование', 'Кроссплатформенное тестирование']
# Кластер 615: ['Жизненный цикл команды']
# Кластер 616: ['Тестирование iOS-приложений', 'тестирование ios']
# Кластер 617: ['Postfix']
# Кластер 618: ['vSphere']
# Кластер 619: ['SketchUp']
# Кластер 620: ['AI', 'ИИ']
# Кластер 621: ['XPath']
# Кластер 622: ['Вторичная адаптация персонала', 'Адаптация персонала']
# Кластер 623: ['Use Case Analysis']
# Кластер 624: ['Верстка']
# Кластер 625: ['самостоятельность', 'Самостоятельность']
# Кластер 626: ['Realm', 'Vrealize']
# Кластер 627: ['Социальные сети']
# Кластер 628: ['iOS SDK']
# Кластер 629: ['Создание сайтов']
# Кластер 630: ['Копирайтинг']
# Кластер 631: ['Реализация маркетинговой стратегии', 'Маркетинговая стратегия', 'Трейд-маркетинговая стратегия', 'Стратегический маркетинг', 'Разработка маркетинговой стратегии', 'Маркетинговые стратегии']
# Кластер 632: ['Поиск персонала', 'Найм персонала']
# Кластер 633: ['Cистемы управления базами данных', 'Администрирование баз данных']
# Кластер 634: ['web3', 'Веб3', 'Web3']
# Кластер 635: ['руководство командой разработчиков']
# Кластер 636: ['Visual Studio C#', 'MS Visual Studio']
# Кластер 637: ['SEO оптимизация']
# Кластер 638: ['Развитие ключевых клиентов']
# Кластер 639: ['Опытный пользователь ПК']
# Кластер 640: ['Product Management', 'Управление продуктами', 'Управление продуктом']
# Кластер 641: ['Оценка персонала']
# Кластер 642: ['МСФО', 'FEC', 'ЦФТ']
# Кластер 643: ['Составление отчетности', 'Составление отчетов', 'Составление баг-репортов']
# Кластер 644: ['TFTP', 'FTP']
# Кластер 645: ['Autodesk Revit']
# Кластер 646: ['Numpy', 'Nagios', 'Node']
# Кластер 647: ['ГОСТ 34', '34 ГОСТ']
# Кластер 648: ['Camunda']
# Кластер 649: ['Web Design', 'Web-проекты']
# Кластер 650: ['OTRS', 'ОКР', 'ОРЭМ', 'ERD']
# Кластер 651: ['Gamedev', 'gamedev', 'GameDev', 'геймдев', 'геймдизайн']
# Кластер 652: ['Ui/UX', 'UI/UX', 'UX/UI']
# Кластер 653: ['Административное управление', 'Менеджмент', 'Управление']
# Кластер 654: ['Финансовая стратегия']
# Кластер 655: ['GitOPS', 'GitOps', 'GitlabCI']
# Кластер 656: ['Поддержка пользователей']
# Кластер 657: ['OpenAPI', 'Open API', 'OpenApi']
# Кластер 658: ['Системы контроля версий']
# Кластер 659: ['Amazon Web Services']
# Кластер 660: ['НКУ', 'НИР', 'НИОКР']
# Кластер 661: ['PRTG', 'RTP', 'ТЭП', 'ВПР', 'СТП']
# Кластер 662: ['NAT', 'NAS', 'NATS']
# Кластер 663: ['Разработка платформы', 'Кроссплатформенная разработка']
# Кластер 664: ['Международные рынки']
# Кластер 665: ['Apache NiFi']
# Кластер 666: ['Анализ текущих финансовых показателей']
# Кластер 667: ['HTML/CSS/JS', 'HTML/CSS']
# Кластер 668: ['Разработка технической документации', 'Обращение с технической документацией', 'ведение технической документации']
# Кластер 669: ['Astra Linux', 'AstraLinux']
# Кластер 670: ['Разработка и внедрение KPI']
# Кластер 671: ['Строительная документация']
# Кластер 672: ['Робототехника', 'роботизация', 'робототехника']
# Кластер 673: ['Perl']
# Кластер 674: ['Business Planning', 'Подготовка бизнес-планов', 'Бизнес-планирование', 'Составление бизнес-плана']
# Кластер 675: ['Серверное оборудование']
# Кластер 676: ['superset', 'Super Set', 'SuperSet', 'Superset']
# Кластер 677: ['Hardware']
# Кластер 678: ['Строительно-отделочные работы']
# Кластер 679: ['Добросовестность', 'Доброжелательность']
# Кластер 680: ['Бренд-менеджмент']
# Кластер 681: ['Wireshark']
# Кластер 682: ['Высокий уровень самоорганизации']
# Кластер 683: ['SSH']
# Кластер 684: ['VictoriaMetrics', 'Victoria Metrics']
# Кластер 685: ['КриптоПро', 'Криптовалюта']
# Кластер 686: ['B2B Marketing', 'B2C-маркетинг', 'B2C маркетинг', 'B2B маркетинг', 'B2B-маркетинг']
# Кластер 687: ['Notion']
# Кластер 688: ['Compose']
# Кластер 689: ['Взаимодействие с контрольными органами', 'Взаимодействие с контролирующими органами', 'Взаимодействие с государственными контролирующими органами', 'Взаимодействие с органами государственного контроля']
# Кластер 690: ['Техническая грамотность', 'техническая грамотность']
# Кластер 691: ['JSP', 'JPA', 'JWT']
# Кластер 692: ['Управление требованиями']
# Кластер 693: ['Ведение рабочей документации']
# Кластер 694: ['Windows Xp']
# Кластер 695: ['AS IS/TO BE mapping']
# Кластер 696: ['1С: Торговля', '1С: Торговля и склад']
# Кластер 697: ['Написание технических заданий']
# Кластер 698: ['HR-метрики']
# Кластер 699: ['разработка документации', 'Разработка документации', 'Разработка рабочей документации', 'Разработка пользовательской документации']
# Кластер 700: ['Навыки делового общения']
# Кластер 701: ['Архитектура доработок', 'Architecture', 'Architect', 'Архитектура']
# Кластер 702: ['Rust']
# Кластер 703: ['коммуникация', 'Научные коммуникации', 'Навыки коммуникации']
# Кластер 704: ['Кортеос', 'Coroutine', 'Coroutines']
# Кластер 705: ['Asana', 'Аудит']
# Кластер 706: ['Корпоративные продажи']
# Кластер 707: ['Системное тестирование']
# Кластер 708: ['Контент-маркетинг']
# Кластер 709: ['Администрирование сайтов']
# Кластер 710: ['RHEL', 'ROI', 'RLS', 'РРЭ']
# Кластер 711: ['Roadmap']
# Кластер 712: ['Оптимизация', 'Оптимизация затрат']
# Кластер 713: ['Мобильное тестирование', 'тестирование мобильных приложений', 'мобильное тестирование']
# Кластер 714: ['Управление разработкой']
# Кластер 715: ['Minio', 'minio']
# Кластер 716: ['Power Pivot', '• Power Pivot']
# Кластер 717: ['Фасилитация']
# Кластер 718: ['webgl', 'WebGL']
# Кластер 719: ['Управление производством', 'Производственный контроль']
# Кластер 720: ['Zend Framework']
# Кластер 721: ['химический анализ', 'Химические методы анализа']
# Кластер 722: ['Компас-3D', 'Компас 3D', '3D']
# Кластер 723: ['Работа с системами аналитики', 'Работа с аналитикой']
# Кластер 724: ['Tarantool']
# Кластер 725: ['JDBC']
# Кластер 726: ['Мониторинг цен']
# Кластер 727: ['next', 'Next']
# Кластер 728: ['Start-up project']
# Кластер 729: ['Progressive Web Applications', 'Web Application Development']
# Кластер 730: ['Контроль поставок', 'Контроль']
# Кластер 731: ['Настройка серверов Apache']
# Кластер 732: ['Spring Data']
# Кластер 733: ['Тестирования баз данных', 'Тестирование баз данных']
# Кластер 734: ['PD', 'DSP', 'SDP', 'UDP']
# Кластер 735: ['Водоснабжение и канализация', 'Системы канализации и водоснабжения']
# Кластер 736: ['Анализ кода', '1с анализ кода']
# Кластер 737: ['Мониторинг СМИ', 'Медиа-мониторинг']
# Кластер 738: ['Коммуникабельность, ответственность']
# Кластер 739: ['Работа на выставках']
# Кластер 740: ['Codeigniter']
# Кластер 741: ['Проектирование высоконагруженных систем']
# Кластер 742: ['Технический надзор', 'Выполнение технического надзора']
# Кластер 743: ['Логическое мышление']
# Кластер 744: ['Аутсорсинг']
# Кластер 745: ['Системы мониторинга сетей', 'Система мониторинга', 'Системы мониторинга']
# Кластер 746: ['Olap (online analytical processing)']
# Кластер 747: ['Restassured', 'Rest Assured']
# Кластер 748: ['R']
# Кластер 749: ['Знание нормативной документации ГОСТ и СНиП']
# Кластер 750: ['Apache Spark']
# Кластер 751: ['Ведение клиентской базы']
# Кластер 752: ['SQL-запросы', 'SQL запросы']
# Кластер 753: ['Реконструкция']
# Кластер 754: ['RAID']
# Кластер 755: ['Altium Designer']
# Кластер 756: ['Авторский надзор']
# Кластер 757: ['Проведение собеседований']
# Кластер 758: ['Telegraf', 'Telegram']
# Кластер 759: ['SignalR', 'Signal R']
# Кластер 760: ['Управление затратами', 'управление бюджетами и затратами']
# Кластер 761: ['Business Intelligence Systems']
# Кластер 762: ['Комьюнити-менеджмент', 'Риск-менеджмент']
# Кластер 763: ['OpenCV']
# Кластер 764: ['Express.js', 'ExpressJS']
# Кластер 765: ['Корпоративная этика']
# Кластер 766: ['Оптимизация запросов']
# Кластер 767: ['Код-ревью']
# Кластер 768: ['SAN', 'Sanic']
# Кластер 769: ['Ad Hoc Analysis', 'Ad hoc анализ']
# Кластер 770: ['Telecom', 'телекоммуникаци', 'Телеком', 'Телекоммуникации']
# Кластер 771: ['ВИС', 'EVM', 'MVI']
# Кластер 772: ['SOAP UI', 'SOAP API']
# Кластер 773: ['Реинжиниринг бизнес-процессов', 'Бизнес-процессы', 'Аудит бизнес-процессов', 'Декомпозиция бизнес-процессов']
# Кластер 774: ['DALI', 'DRY', 'DAST']
# Кластер 775: ['Вентиляция и кондиционирование', 'системы вентиляции и кондиционирования']
# Кластер 776: ['ArchiCAD']
# Кластер 777: ['WPF']
# Кластер 778: ['мобильная разработка', 'Разработчик мобильных приложений', 'Разработка мобильных приложений', 'Мобильная разработка']
# Кластер 779: ['Zustand']
# Кластер 780: ['Составление сметно-проектной документации', 'Составление документации']
# Кластер 781: ['Intellij IDEA']
# Кластер 782: ['Alert Manager', 'Alertmanager', 'alertmanager']
# Кластер 783: ['Подбор контента', 'Наполнение контентом']
# Кластер 784: ['Тестирование Android-приложений', 'Тестирование Android']
# Кластер 785: ['GSM']
# Кластер 786: ['Анализ ФХД', 'RFM-анализ']
# Кластер 787: ['Инжиниринг']
# Кластер 788: ['SSDLC', 'SDLC']
# Кластер 789: ['Строительные технологии']
# Кластер 790: ['SEO-копирайтинг']
# Кластер 791: ['Windows Server 2012']
# Кластер 792: ['Строительный контроль']
# Кластер 793: ['Написание инструкций']
# Кластер 794: ['Шаблоны проектирования', 'Design Patterns']
# Кластер 795: ['Договоры аренды', 'договора аренды']
# Кластер 796: ['менеджер проекта', 'руководитель проекта', 'Руководитель проекта', 'руководитель проектов', 'руководство проектами', 'руководство проектом', 'Менеджер проектов', 'менеджер проектов', 'Руководитель проектов', 'Менеджер проекта', 'project manager']
# Кластер 797: ['Тестирование безопасности']
# Кластер 798: ['Производственное планирование']
# Кластер 799: ['Social Media Marketing']
# Кластер 800: ['Составление тест-кейсов']
# Кластер 801: ['Электроэнергетика', 'силовая электроника', 'Электроснабжение', 'Электроника', 'Электропривод']
# Кластер 802: ['Коммерческая недвижимость', 'Коммерчекая недвижимость']
# Кластер 803: ['BTL', 'БИТ.MDT']
# Кластер 804: ['SWOT анализ', 'SWOT-анализ']
# Кластер 805: ['OpenGL']
# Кластер 806: ['aiohttp', 'AioHTTP', 'Aiohttp']
# Кластер 807: ['Java-core', 'Core Java', 'Java Core', 'JavaCore']
# Кластер 808: ['Wifi networks', 'Wi-Fi', 'wifi']
# Кластер 809: ['Владение С++', 'С++', 'С/С++']
# Кластер 810: ['Схемотехника электронного оборудования']
# Кластер 811: ['Fastlane', 'Fastify']
# Кластер 812: ['TeamViewer']
# Кластер 813: ['Gherkin', 'Grunt']
# Кластер 814: ['WS', 'WSDL']
# Кластер 815: ['Bluetooth']
# Кластер 816: ['Ef Core', 'EF Core', 'EF core']
# Кластер 817: ['Eltex']
# Кластер 818: ['Axios']
# Кластер 819: ['Готовность к командировкам']
# Кластер 820: ['Internet', 'ethernet']
# Кластер 821: ['User Flow']
# Кластер 822: ['LAMP', 'OLAP']
# Кластер 823: ['Сетевое оборудование', 'Настройка сетевого оборудования']
# Кластер 824: ['Adobe After Effects', 'Adobe After Effect']
# Кластер 825: ['Диаграмма Ганта']
# Кластер 826: ['Анализ тестирования']
# Кластер 827: ['React/Redux']
# Кластер 828: ['Монтаж ЛВС']
# Кластер 829: ['Redash', 'Redpanda', 'RedHat']
# Кластер 830: ['Выездное обслуживание оборудования', 'Выездное обслуживание']
# Кластер 831: ['Работа с дебиторской задолженностью']
# Кластер 832: ['Умение организовать работу']
# Кластер 833: ['Дашборды', 'дашборды']
# Кластер 834: ['ServiceDesk', 'Сервисное обслуживание', 'Облачные сервисы', 'Сервис']
# Кластер 835: ['Vault']
# Кластер 836: ['Разработка логистики', 'Разработка Логистики']
# Кластер 837: ['Гибкость', 'Flexibility']
# Кластер 838: ['KISS']
# Кластер 839: ['1С: Логистика']
# Кластер 840: ['ActiveMQ']
# Кластер 841: ['API Gateway']
# Кластер 842: ['Hbase', 'HBase']
# Кластер 843: ['Диагностика ПК']
# Кластер 844: ['Оптимизация логистических процессов']
# Кластер 845: ['Разрешительная документация', 'Исходно-разрешительная документация']
# Кластер 846: ['Запуск маркетинговых кампаний', 'Планирование маркетинговых кампаний']
# Кластер 847: ['Желание расти и развиваться', 'Желание работать и развиваться', 'Желание учиться и развиваться']
# Кластер 848: ['ARM']
# Кластер 849: ['MS Windows (10)', 'Windows 10', 'ОС MS Windows 10', 'Microsoft Windows 7 Microsoft Windows 10', 'Windows 10/11']
# Кластер 850: ['ЭДО', 'СЭД', 'ЕСТД', 'ЦОД', 'ЕХД', 'DECT']
# Кластер 851: ['1С: Производство']
# Кластер 852: ['Уникальное торговое предложение']
# Кластер 853: ['CODESYS']
# Кластер 854: ['WSUS']
# Кластер 855: ['Межсетевые экраны']
# Кластер 856: ['SQLite']
# Кластер 857: ['Транспортная логистика']
# Кластер 858: ['Автоматизация учета']
# Кластер 859: ['Google Ads', 'Google AdWords']
# Кластер 860: ['ПЛИС', 'БПЛА', 'ПЛК']
# Кластер 861: ['Урегулирование конфликтов', 'Разрешать конфликтные ситуации', 'Улаживание конфликтов']
# Кластер 862: ['поддержка', 'Support', 'support']
# Кластер 863: ['WCF']
# Кластер 864: ['PyCharm', 'PyTorch']
# Кластер 865: ['SMM-стратегия']
# Кластер 866: ['Delfi', 'Delphi']
# Кластер 867: ['Вывод продукта на рынок']
# Кластер 868: ['ARIS']
# Кластер 869: ['InfluxDB', 'influxdb']
# Кластер 870: ['Google Data Studio']
# Кластер 871: ['Планирование затрат']
# Кластер 872: ['Juniper']
# Кластер 873: ['Slack']
# Кластер 874: ['Преобразование данных', 'Обмен данных', 'Конвертация данных']
# Кластер 875: ['Unit-экономика']
# Кластер 876: ['AllureTestOps', 'TestOps', 'Allure TestOps', 'Allure Testops']
# Кластер 877: ['1C: Торговля и склад', '1С: Бухгалтерия и склад']
# Кластер 878: ['Яндекс.Директ']
# Кластер 879: ['TFS', 'TS']
# Кластер 880: ['Многопоточное программирование', 'Multithread Programming']
# Кластер 881: ['Ремонт оборудования']
# Кластер 882: ['Ответственность и пунктуальность', 'Ответственность и исполнительность']
# Кластер 883: ['SMTP/POP3/IMAP']
# Кластер 884: ['NPM', 'PMI']
# Кластер 885: ['Первичные документы', 'первичный документооборот']
# Кластер 886: ['3D Моделирование']
# Кластер 887: ['Маркетинговый аудит']
# Кластер 888: ['Разработка концепции']
# Кластер 889: ['Ведение активных клиентов']
# Кластер 890: ['Terminal Server', 'Terminal Services']
# Кластер 891: ['UX-исследования']
# Кластер 892: ['express', 'Express']
# Кластер 893: ['Dapper']
# Кластер 894: ['Google Tag Manager']
# Кластер 895: ['Системы виртуализации', 'Система виртуализации']
# Кластер 896: ['аккуратность в отчетах и оценках']
# Кластер 897: ['S3']
# Кластер 898: ['Планирование работ', 'Оперативное планирование']
# Кластер 899: ['Customer Journey Mapping']
# Кластер 900: ['1С:Смета', '1С: Склад']
# Кластер 901: ['Разработка бизнес-модели', 'Бизнес-моделирование']
# Кластер 902: ['Bitrix Framework']
# Кластер 903: ['Оптимизация воронки продаж']
# Кластер 904: ['Организация и контроль работы персонала']
# Кластер 905: ['SASS/LESS', 'СКС/ЛВС', 'SASS/SCSS']
# Кластер 906: ['Первичное обследование']
# Кластер 907: ['Адекватность', 'Педантичность', 'Аккуратность', 'аккуратность']
# Кластер 908: ['Управление эффективностью']
# Кластер 909: ['swarm']
# Кластер 910: ['PGW', 'GMP', 'ПГ ПГС', 'BGP']
# ...
# Кластер 3331: ['Высшее техническое образование']
# Кластер 3332: ['Lumion']
# Кластер 3333: ['Командные метрики']
# Кластер 3334: ['коммуникация с проектной командой']
# Кластер 3335: ['FPSU']
# Кластер 3336: ['Сегментация рынка']
# Кластер 3337: ['платформа управления уязвимостями']
# Кластер 3338: ['gitlab']
# Кластер 3339: ['Grid']
# Кластер 3340: ['Node-RED']
# Кластер 3341: ['Qemu-KVM']
# Кластер 3342: ['зип']
# Кластер 3343: ['Инвестиционный опыт']
# Кластер 3344: ['TypeScript, CSS, HTML']
# Кластер 3345: ['Terrasoft Creatio']
# Кластер 3346: ['Google play', 'Google Play']
# Кластер 3347: ['fit out']
# Кластер 3348: ['Способность быстро вникать в новые процессы']
# Кластер 3349: ['Маркетинг услуг']
# Кластер 3350: ['Написание бизнес-требований']
# Кластер 3351: ['Проведение индивидуальных занятий']
# Кластер 3352: ['MRCPv2']
# Кластер 3353: ['запорно-регулирующая арматура']
# Кластер 3354: ['Java, Kotlin, Android']
# Кластер 3355: ['WB, Ozon, Lamoda, Yandex Market, MegaMarket']
# Кластер 3356: ['Proxyman']
# Кластер 3357: ['нвф', 'NiFi']
# Кластер 3358: ['rs-485']
# Кластер 3359: ['Android tv', 'Android TV']
# Кластер 3360: ['Опыт администрирования операционных систем семейства Windows и Linux']
# Кластер 3361: ['System Center Configuration Manager']
# Кластер 3362: ['Microsoft Sql Server', 'СУБД MSSQL']
# Кластер 3363: ['Turbo Pascal']
# Кластер 3364: ['middle developer']
# Кластер 3365: ['Еnterprise']
# Кластер 3366: ['Expo']
# Кластер 3367: ['прогнозирование изменений метрик']
# Кластер 3368: ['2линия']
# Кластер 3369: ['Solidity']
# Кластер 3370: ['Mentoring']
# Кластер 3371: ['Hangfire']
# Кластер 3372: ['Контроль технологических процессов']
# Кластер 3373: ['Kong']
# Кластер 3374: ['Flyway']
# Кластер 3375: ['Поисковая оптимизация сайтов']
# Кластер 3376: ['Бюджетирование ФОТ']
# Кластер 3377: ['Gitea', 'Гектаро']
# Кластер 3378: ['junior devops']
# Кластер 3379: ['Anykey']
# Кластер 3380: ['Jinja2']
# Кластер 3381: ['Ubiquiti Networks']
# Кластер 3382: ['MS Internet Explorer']
# Кластер 3383: ['Подбор оборудования']
# Кластер 3384: ['Менеджмент организаций']
# Кластер 3385: ['drweb']
# Кластер 3386: ['гидротехника']
# Кластер 3387: ['уязвимость']
# Кластер 3388: ['OC Linux']
# Кластер 3389: ['RS-232']
# Кластер 3390: ['Google Looker Studio']
# Кластер 3391: ['OOP']
# Кластер 3392: ['C11']
# Кластер 3393: ['SQL (включая индексы)']
# Кластер 3394: ['Способность самостоятельно принимать решения']
# Кластер 3395: ['JFrog Artifactory']
# Кластер 3396: ['Опыт при строительстве многоквартирных домов']
# Кластер 3397: ['Высокая энергичность и инициативность']
# Кластер 3398: ['Мониторинг изменения стандартов']
# Кластер 3399: ['гидроэлектростанции']
# Кластер 3400: ['поддержка высоконагруженных систем']
# Кластер 3401: ['Investment Banking']
# Кластер 3402: ['Управление лояльностью потребителей']
# Кластер 3403: ['цифровой гигант']
# Кластер 3404: ['IPS']
# Кластер 3405: ['DESKTOP']
# Кластер 3406: ['Service Workers']
# Кластер 3407: ['Dialux']
# Кластер 3408: ['Клининг']
# Кластер 3409: ['Docker и Kubernetes']
# Кластер 3410: ['Программист SQL']
# Кластер 3411: ['Локализация продукта']
# Кластер 3412: ['Webasyst']
# Кластер 3413: ['OLAP кубы']
# Кластер 3414: ['Foreman']
# Кластер 3415: ['Kaspresso']
# Кластер 3416: ['Проектные институты']
# Кластер 3417: ['Написание продающих текстов']
# Кластер 3418: ['График выполнения проектов']
# Кластер 3419: ['ArchOps']
# Кластер 3420: ['Корреляционный анализ']
# Кластер 3421: ['Преподавание']
# Кластер 3422: ['навесные-вентилируемые фасады']
# Кластер 3423: ['ES6+', 'ES6+ синтаксис']
# Кластер 3424: ['Схемотехника']
# Кластер 3425: ['Xamarin']
# Кластер 3426: ['Kickidler']
# Кластер 3427: ['image filtering']
# Кластер 3428: ['SolidWorks']
# Кластер 3429: ['Technical Translation']
# Кластер 3430: ['dApps']
# Кластер 3431: ['Infrastructure-as-Code']
# Кластер 3432: ['VanillaJS']
# Кластер 3433: ['Linux Python Pytest']
# Кластер 3434: ['Upsource']
# Кластер 3435: ['руководитель отдела бизнес-систем']
# Кластер 3436: ['Система домашней автоматизации "Умный дом"']
# Кластер 3437: ['веб приложение']
# Кластер 3438: ['Консультирование пользователей']
# Кластер 3439: ['Водительское удостоверение категории B']
# Кластер 3440: ['Portainer']
# Кластер 3441: ['nginx, postfix, squid, dns']
# Кластер 3442: ['Знание английского языка']
# Кластер 3443: ['Zephyr Scale']
# Кластер 3444: ['Администрирование IIS, Nginx']
# Кластер 3445: ['Штукатурные работы']
# Кластер 3446: ['Antifraud']
# Кластер 3447: ['Inferno']
# Кластер 3448: ['core']
# Кластер 3449: ['Windows Server 16-22']
# Кластер 3450: ['Английский язык (базовый)']
# Кластер 3451: ['Разработка Ботов', 'Разработка ботов']
# Кластер 3452: ['Регистрация лекарственный средств']
# Кластер 3453: ['Семейная медицина']
# Кластер 3454: ['MS Axapta']
# Кластер 3455: ['Работа с пользователями']
# Кластер 3456: ['сети передачи данных']
# Кластер 3457: ['Подбор стажеров']
# Кластер 3458: ['CVS']
# Кластер 3459: ['Настройка оборудования для видеосъёмки']
# Кластер 3460: ['OWASP Mobile Top 10', 'OWASP Top 10']
# Кластер 3461: ['Microsoft System Center']
# Кластер 3462: ['backend PHP']
# Кластер 3463: ['HOC', 'HACCP']
# Кластер 3464: ['OpenCart']
# Кластер 3465: ['Mesos, Marathon']
# Кластер 3466: ['Passolo']
# Кластер 3467: ['Внедрение сервисных услуг']
# Кластер 3468: ['ScrollTrigger']
# Кластер 3469: ['архитектурное программирование']
# Кластер 3470: ['системная разработка']
# Кластер 3471: ['Layered pattern']
# Кластер 3472: ['NHibernate']
# Кластер 3473: ['ClearML']
# Кластер 3474: ['Клинические исследования', 'Координатор клинических исследований']
# Кластер 3475: ['Telegram API']
# Кластер 3476: ['чувство юмора']
# Кластер 3477: ['Hive Metastore']
# Кластер 3478: ['NSQ']
# Кластер 3479: ['SAP Business Objects']
# Кластер 3480: ['Обязательность']
# Кластер 3481: ['Enzyme']
# Кластер 3482: ['Желательно: знания сетевой инфраструктуры, опыт работы в среде Astra Linux, решение задач DevOps']
# Кластер 3483: ['Главбух']
# Кластер 3484: ['EcmaScript6+']
# Кластер 3485: ['Менеджер проекта - комплектация, продажи, дизайн интерьера, мебель']
# Кластер 3486: ['Ansible Composer']
# Кластер 3487: ['TOS системы']
# Кластер 3488: ['Poetry']
# Кластер 3489: ['Linux network stack']
# Кластер 3490: ['Рекламная съемка']
# Кластер 3491: ['ClickHouse DB']
# Кластер 3492: ['SDK/WDK API']
# Кластер 3493: ['Разработка в системе 1С: УТ']
# Кластер 3494: ['Опыт работы в CRM']
# Кластер 3495: ['Test Design']
# Кластер 3496: ['Отчётность о результатах разработки']
# Кластер 3497: ['Разработка отчетов']
# Кластер 3498: ['Self-hosted']
# Кластер 3499: ['CS-cart']
# Кластер 3500: ['Технический английский']
# Кластер 3501: ['OSI (TCP/IP)']
# Кластер 3502: ['Сопровождение договоров с заказчиками и субподрядчиками']
# Кластер 3503: ['IT оборудование']
# Кластер 3504: ['Опыт работы с REST api, OAuth авторизациями']
# Кластер 3505: ['Capex']
# Кластер 3506: ['Рассылка сообщений']
# Кластер 3507: ['Переработка полимеров']
# Кластер 3508: ['Бюджетирование маркетинговой стратегии']
# Кластер 3509: ['typescripot']
# Кластер 3510: ['опыт работы с линейкой ОС Win 7-11']
# Кластер 3511: ['Серверные операционные системы']
# Кластер 3512: ['Оптоволокно']
# Кластер 3513: ['Интеграция с API', 'интеграция со сторонними API']
# Кластер 3514: ['Qt5']
# Кластер 3515: ['Vertica']
# Кластер 3516: ['Знание устройства автомобиля']
# Кластер 3517: ['разработка мобильных приложений на Unity']
# Кластер 3518: ['SAP HANA']
# Кластер 3519: ['• Tabular Editor']
# Кластер 3520: ['Ветеринария']
# Кластер 3521: ['Умение читать чертежи и электрические схемы']
# Кластер 3522: ['Переговоры с заказчиками']
# Кластер 3523: ['JRPC']
# Кластер 3524: ['Rest API/ WebSockets']
# Кластер 3525: ['Работа с доменами']
# Кластер 3526: ['Кэширование']
# Кластер 3527: ['Архитектура изделий']
# Кластер 3528: ['HTML Components']
# Кластер 3529: ['Проведение деловых встреч']
# Кластер 3530: ['DevOps и концепции CI/CD']
# Кластер 3531: ['Дата-каталог']
# Кластер 3532: ['Опыт работы с системами дашбординга, мониторинга, BI']
# Кластер 3533: ['Лазерная техника']
# Кластер 3534: ['LiveOps']
# Кластер 3535: ['Запуск федеральных рекламных кампаний']
# Кластер 3536: ['Продажи в инженерных изысканиях']
# Кластер 3537: ['Доработка функционала']
# Кластер 3538: ['ember.js']
# Кластер 3539: ['Gitlab, GitlabCI, Hashicorp Vault']
# Кластер 3540: ['POSm']
# Кластер 3541: ['Payments']
# Кластер 3542: ['Ingress']
# Кластер 3543: ['Управление личными ассистентами']
# Кластер 3544: ['Sysinternals Suite']
# Кластер 3545: ['АТС Рanasonic']
# Кластер 3546: ['ActiveDirectory']
# Кластер 3547: ['Pyton', 'Phyton', 'phyton']
# Кластер 3548: ['C++/Qt']
# Кластер 3549: ['администрирование межсетевых экранов']
# Кластер 3550: ['Уверенный пользователь ПК и офисных программ']
# Кластер 3551: ['Cube.js']
# Кластер 3552: ['Государственные проекты']
# Кластер 3553: ['4PL']
# Кластер 3554: ['бюджетирование и анализ финансовых смет строительных проектов']
# Кластер 3555: ['Kaspersky EDR']
# Кластер 3556: ['Английский B2']
# Кластер 3557: ['Psalm']
# Кластер 3558: ['WebCrypto API']
# Кластер 3559: ['macos']
# Кластер 3560: ['Whatsapp']
# Кластер 3561: ['Конфигурация серверного оборудования']
# Кластер 3562: ['Juniper equipment']
# Кластер 3563: ['MLOps']
# Кластер 3564: ['Знания HTML, JSON']
# Кластер 3565: ['Написание inline-документ']
# Кластер 3566: ['ASTRA Linux', 'astra linux']
# Кластер 3567: ['звуковые системы']
# Кластер 3568: ['Печатные формы']
# Кластер 3569: ['Встраиваемое ПО']
# Кластер 3570: ['agile-трансформации']
# Кластер 3571: ['Автоматизированная система']
# Кластер 3572: ['прораб']
# Кластер 3573: ['XCTest']
# Кластер 3574: ['урбанистика']
# Кластер 3575: ['Optaplanner']
# Кластер 3576: ['Security architecture']
# Кластер 3577: ['Машиностроение']
# Кластер 3578: ['Principle']
# Кластер 3579: ['гибрид казуальные']
# Кластер 3580: ['Сопровождение арендных отношений']
# Кластер 3581: ['CentOS, Ubuntu']
# Кластер 3582: ['Standard']
# Кластер 3583: ['Java 17+']
# Кластер 3584: ['полный цикл']
# Кластер 3585: ['HTML, CSS (SASS); JavaScript (ES6); БЭМ; Webpack, npm, ESLlint, Babel; Git; PHP; TypeScript, React.']
# Кластер 3586: ['Observability']
# Кластер 3587: ['Учет ТМЦ']
# Кластер 3588: ['Умение вести деловую переписку']
# Кластер 3589: ['Владение MicrosoftOffice на уровне опытного пользователя']
# Кластер 3590: ['TOS/WMS']
# Кластер 3591: ['Подготовка комментариев для прессы']
# Кластер 3592: ['Свободное владение английским языком']
# Кластер 3593: ['Клиентский сервис']
# Кластер 3594: ['Ведущий (Lead)']
# Кластер 3595: ['Основы маркетинга']
# Кластер 3596: ['АВ тестирование']
# Кластер 3597: ['EtherCAT']
# Кластер 3598: ['Набор команды']
# Кластер 3599: ['Yandex Cloud Platform']
# Кластер 3600: ['Аудит предписаний ГПН']
# Кластер 3601: ['Dremio']
# Кластер 3602: ['Опыт администрирования СУБД PostgreSQL, Tarantool, Greenplum, ClickHouse;']
# Кластер 3603: ['химия']
# Кластер 3604: ['rive']
# Кластер 3605: ['Разработка поисковых технологий']
# Кластер 3606: ['Босс-Кадровик']
# Кластер 3607: ['Pest-Анализ']
# Кластер 3608: ['Управление по целям']
# Кластер 3609: ['mongo', 'mondrian']
# Кластер 3610: ['трансгуманизм']
# Кластер 3611: ['HIL']
# Кластер 3612: ['Продажи ИТ-услуг']
# Кластер 3613: ['Программирование ПЛК']
# Кластер 3614: ['Продуктолог']
# Кластер 3615: ['Хранение документов']
# Кластер 3616: ['Firmware']
# Кластер 3617: ['СНИПы']
# Кластер 3618: ['Mikotik']
# Кластер 3619: ['Анализ судебной практики']
# Кластер 3620: ['Patroni']
# Кластер 3621: ['Написание процедур']
# Кластер 3622: ['OSCP']
# Кластер 3623: ['мебель по индивидуальным проектам']
# Кластер 3624: ['Проектирование декораций']
# Кластер 3625: ['скала-Р']
# Кластер 3626: ['Организованность и внимание к деталям']
# Кластер 3627: ['Тестирование сайтов']
# Кластер 3628: ['Verification']
# Кластер 3629: ['Разработка тестирования']
# Кластер 3630: ['NUnit']
# Кластер 3631: ['Аналитическая работа']
# Кластер 3632: ['Karma']
# Кластер 3633: ['Ktor', 'Qurator']
# Кластер 3634: ['Горный туризм']
# Кластер 3635: ['Core ML']
# Кластер 3636: ['Fit - Out']
# Кластер 3637: ['Разработчик BI']
# Кластер 3638: ['ISO9001/TS16949 APQP']
# Кластер 3639: ['NPD']
# Кластер 3640: ['ORM Eloquent']
# Кластер 3641: ['Pytest-bdd']
# Кластер 3642: ['OpenLens']
# Кластер 3643: ['Redux-thunk']
# Кластер 3644: ['.NET 5.0']
# Кластер 3645: ['администрирование Windows Server, Active Directory']
# Кластер 3646: ['Nuxt.js v3']
# Кластер 3647: ['FW Cucumber']
# Кластер 3648: ['Bubble']
# Кластер 3649: ['DigitalOcean']
# Кластер 3650: ['стратегическое развитие клиентов']
# Кластер 3651: ['Freeswitch']
# Кластер 3652: ['• Стратегический образ мышления']
# Кластер 3653: ['cordova']
# Кластер 3654: ['Хорошие сенсорные способности']
# Кластер 3655: ['Герметик']
# Кластер 3656: ['знание английского языка будет преимуществом']
# Кластер 3657: ['data analyst']
# Кластер 3658: ['wasm']
# Кластер 3659: ['Аppium']
# Кластер 3660: ['J2EE']
# Кластер 3661: ['оформление запросов']
# Кластер 3662: ['опыт работы в крупных строительных компаниях']
# Кластер 3663: ['Технологии металлообработки']
# Кластер 3664: ['Администрирование Windows']
# Кластер 3665: ['Nemo Handy']
# Кластер 3666: ['Лабораторная диагностика']
# Кластер 3667: ['Немецкий язык']
# Кластер 3668: ['1С-Рарус']
# Кластер 3669: ['Dynamic SQL']
# Кластер 3670: ['Tax Optimisation']
# Кластер 3671: ['OFDM']
# Кластер 3672: ['system administration']
# Кластер 3673: ['SSAS Tabular']
# Кластер 3674: ['Умение аналитически мыслить']
# Кластер 3675: ['ETW', 'ТЭЦ']
# Кластер 3676: ['pyrogram']
# Кластер 3677: ['Реставрационные работы']
# Кластер 3678: ['phpMyAdmin']
# Кластер 3679: ['Универсальность']
# Кластер 3680: ['Aria Operations']
# Кластер 3681: ['HTML-верстка']
# Кластер 3682: ['Retention']
# Кластер 3683: ['LinkedIn']
# Кластер 3684: ['Запуск в серию']
# Кластер 3685: ['Документирование бизнес-процессов']
# Кластер 3686: ['СКД (система компоновки данных)']
# Кластер 3687: ['VDI']
# Кластер 3688: ['Страхование']
# Кластер 3689: ['NodeJs']
# Кластер 3690: ['Банк-клиент']
# Кластер 3691: ['Поддержка работы офиса']
# Кластер 3692: ['sklearn']
# Кластер 3693: ['Любовь к людям']
# Кластер 3694: ['Cats']
# Кластер 3695: ['Трассировка печатных плат']
# Кластер 3696: ['KAPE']
# Кластер 3697: ['Формирование пула лояльных СМИ']
# Кластер 3698: ['LGD']
# Кластер 3699: ['Цифровые сервисы']
# Кластер 3700: ['Базы данных pg/sqlite']
# Кластер 3701: ['Поиск поставщиков']
# Кластер 3702: ['Экспертиза документов']
# Кластер 3703: ['Анализ вредоносного ПО']
# Кластер 3704: ['Подготовка к выставкам']
# Кластер 3705: ['структура продаж']
# Кластер 3706: ['PRIMEVUE']
# Кластер 3707: ['in-app']
# Кластер 3708: ['Формирование ассортимента']
# Кластер 3709: ['SQL Plus']
# Кластер 3710: ['I2C']
# Кластер 3711: ['Дистрибуция']
# Кластер 3712: ['Развитие IT инфраструктуры']
# Кластер 3713: ['Serpstat']
# Кластер 3714: ['Veracode']
# Кластер 3715: ['Basecamp']
# Кластер 3716: ['Знание маркетплейсов']
# Кластер 3717: ['Simple-SCADA']
# Кластер 3718: ['Infrastructure as Code (IaC)']
# Кластер 3719: ['IWork']
# Кластер 3720: ['Antis spam']
# Кластер 3721: ['team city или Jenkins']
# Кластер 3722: ['Инженер-разработчик тестов']
# Кластер 3723: ['Рекомендательные системы']
# Кластер 3724: ['тестовые сценарии']
# Кластер 3725: ['AIM/DCIM']
# Кластер 3726: ['Построение дашбордов']
# Кластер 3727: ['Разработка графиков производства работ']
# Кластер 3728: ['Инфраструктура']
# Кластер 3729: ['MV-паттерны']
# Кластер 3730: ['Поиск и привлечение партнеров']
# Кластер 3731: ['бригадир']
# Кластер 3732: ['OpenMetadata']
# Кластер 3733: ['ГОСТ РВ']
# Кластер 3734: ['составление заявки на материалы']
# Кластер 3735: ['разработка Хранилищ данных']
# Кластер 3736: ['UA/UX']
# Кластер 3737: ['Экология']
# Кластер 3738: ['Разработка под Android']
# Кластер 3739: ['Exchange Load Balancing']
# Кластер 3740: ['Masternodes']
# Кластер 3741: ['Разработка с использованием Яндекс-карт и геолокации']
# Кластер 3742: ['• Навыки работы с фреймворками для автоматического тестирования (например, Jest, Mocha)']
# Кластер 3743: ['Veeam B&R']
# Кластер 3744: ['умение работать в команде и готовность решать сложные задачи в максимально короткие сроки']
# Кластер 3745: ['Auth 2.0']
# Кластер 3746: ['календарно-сетевое планирование']
# Кластер 3747: ['Продажи технически сложного продукта']
# Кластер 3748: ['Hapi']
# Кластер 3749: ['DMX512']
# Кластер 3750: ['Siebel']
# Кластер 3751: ['Redis-cluster']
# Кластер 3752: ['Uvicorn']
# Кластер 3753: ['Взаимодействие с Заказчиком']
# Кластер 3754: ['Компенсации и льготы']
# Кластер 3755: ['Reddis']
# Кластер 3756: ['параллельные файловые системы']
# Кластер 3757: ['Опыт в администрирование ip-телефонии']
# Кластер 3758: ['http-сервис']
# Кластер 3759: ['remote']
# Кластер 3760: ['Офис']

# %%
replacements = {}

for key_skill_cluster in key_skill_clusters:
    most_popular_skill = max(key_skill_cluster, key=lambda key_skill_name: key_skill_frequencies.get(key_skill_name, 0))
    
    for key_skill_name in key_skill_cluster:
        replacements[key_skill_name] = most_popular_skill

# %%
with open(f'{base_dir}/output/replacements.json', 'w+', encoding='utf-8') as f:
    json.dump(replacements, f, ensure_ascii=False, indent=4)
